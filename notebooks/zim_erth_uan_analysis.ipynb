# %%
# from utils.get_docs import get_stonk_data
# from datetime import datetime
from utils.get_stonk_data import analyze_info, get_marketbeat_comp
from IPython.core.display import display, HTML

stocks = ["ZIM", "UAN", "CM.TO", "POW.TO", "ERTH.CN"]
stock_doc_names = ["ZIM:US", "UAN:US", "CM", "POW" "ERTH:CNX"]
stock_urls = [
    "https://www.marketbeat.com/stocks/NYSE/ZIM/competitors-and-alternatives/",
    "https://www.marketbeat.com/stocks/NYSE/UAN/competitors-and-alternatives/",
    "https://www.marketbeat.com/stocks/TSE/CM/competitors-and-alternatives/",
    "https://www.marketbeat.com/stocks/TSE/POW/competitors-and-alternatives/"
]

for index, stock in enumerate(stock_doc_names):
    # start_date
    # start_date = "2015-01-01"
    # end date today in YYYY-MM-DD format
    # currentDate = datetime.now().strftime('%Y-%m:%d')
    # get_stonk_data(stock, start_date, currentDate)
    if len(stock_urls) > index:
        dfs = get_marketbeat_comp(stock_urls[index])
        for df in dfs:
            display(HTML(df.to_html(index=False)))
            # print(df)
    stock_name = stocks[index]
    if stock_name:
        analyze_info(stock_name)

    # fundamental data
# Out:
# /tmp/ipykernel_9212/3371026380.py:3: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# ic| 'Eating ice cream'
# {"operationName": "getCompanyFilings", "variables": {"symbol": "ZIM:US", "fromDate": "2015-01-01", "toDate": "2022-03:27", "limit": 2000}, "query": "query getCompanyFilings(\n      $symbol: String!\n      $fromDate: String\n      $toDate: String\n      $limit: Int\n    ) {\n      filings: getCompanyFilings(\n        symbol: $symbol\n        fromDate: $fromDate\n        toDate: $toDate\n        limit: $limit\n      ) {\n        size\n        filingDate\n        description\n        name\n        urlToPdf\n        __typename\n      }\n    }"}
# ic| filings: []
# {'filings': []}
# {'filings': []}
# ...
# Execution time in seconds: 0.0036559104919433594
# Total downloads: 0
# No filings found
# <table border="1" class="dataframe">
#   <thead>
# ...
